# %%
import pandas as pd
import glob
import os
from IPython.display import display, HTML


os.chdir('/notebooks/aftdbcsv')
files=glob.glob('*.csv')

i=1

columns=pd.read_csv(files[0]).columns
print(columns)
df = pd.DataFrame(columns=columns)
print(df.shape)
for file in sorted(files):
    name=file[:-4]
    print(name)
    row=pd.read_csv(file)
    df=df.append(row)
# Out:
# Index(['commonPattern_amp_min', 'commonPattern_amp_max',
#        'commonPattern_amp_mean', 'commonPattern_amp_std',
#        'commonPattern_amp_median', 'commonPattern_amp_iqr',
#        'commonPattern_amp_gini', 'commonPattern_width_min',
#        'commonPattern_width_max', 'commonPattern_width_mean',
#        ...
#        'combined_afOrNoise', 'combined_is_normal', 'combined_is_normal_old',
#        'combined_is_noise', 'combined_n_over_noise_th',
#        'combined_normalOrOther_new', 'combined_normalOrAF_new',
#        'combined_normalOrNoise_new', 'combined_afOrOther_new',
#        'combined_otherOrNoise'],
#       dtype='object', length=386)
# (0, 386)
# A08529
# A08530
# A08531
# A08532
# A08533
# A08534
# A08535
# A08536
# A08537
# A08538
# A08539
# A08540
# A08541
# A08542
# A08543
# A08544
# A08545
# A08546
# A08547
# A08548
# A08549
# A08550
# A08551
# A08552
# A08553
# A08554
# A08555
# A08556
# A08557
# A08558
# A08559
# A08560
# A08561
# A08562
# A08563
# A08564
# ...

# %%
df
# Out:
#     commonPattern_amp_min  commonPattern_amp_max  commonPattern_amp_mean  \
# 0                1.346008               1.788236                1.553178
# 0                0.247370               0.671890                0.477676
# 0                0.953871               1.540102                1.293927
# 0                0.149022               0.662639                0.347806
# 0                1.273673               1.660910                1.457526
# 0                0.097041               0.429217                0.236187
# 0                0.223055               0.300362                0.272983
# 0                0.090891               0.415441                0.157049
# 0                0.871223               1.187496                1.022468
# 0                0.254785               0.562732                0.380705
# 0                2.018121               2.779545                2.422383
# 0                0.688003               1.105881                0.853266
# ...
